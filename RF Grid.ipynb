# %%
# Data Collection
import pandas as pd
dataset = pd.read_csv('insurance_pre.csv')

# %%
# Data Preprocessing
dataset = pd.get_dummies(dataset, drop_first=True)
# Display the columns of the dataset
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
X = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
y = dataset['charges']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Model Training
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters = {
    'criterion': ['squared_error', 'absolute_error', 'poisson'],
    'max_features': ['auto', 'sqrt', 'log2'],
    'n_estimators': [100, 200, 300]
}
grid = GridSearchCV(RandomForestRegressor(), parameters, refit=True, n_jobs=-1, verbose=3)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# c:\Users\Z0031XFH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 45 fits failed out of a total of 135.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Z0031XFH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Z0031XFH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Z0031XFH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\Z0031XFH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 39 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Z0031XFH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Z0031XFH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Z0031XFH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\Z0031XFH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Z0031XFH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.81370561 0.81226089 0.81293824
#  0.81179007 0.81342792 0.81104974        nan        nan        nan
#  0.811315   0.8123658  0.81438859 0.81387546 0.81234333 0.8119095
#         nan        nan        nan 0.81296383 0.81256036 0.81368973
#  0.81427779 0.81527996 0.81282304]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300]},
#              verbose=3)

# %%
from sklearn.tree import DecisionTreeRegressor

GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
 verbose=3,
             param_grid={'C': [100, 1000, 2000], 'gamma': ['scale', 'auto'],
                         'kernel': ['linear', 'rbf']})
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'C': [100, 1000, 2000], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf']},
#              verbose=3)

# %%
results = grid.cv_results_

# %%
print ("Best parameters found: ", grid.best_params_)
print ("Best cross-validation score: ", grid.best_score_)
# Out:
# Best parameters found:  {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 200}
# Best cross-validation score:  0.8152799562447599

# %%
table = pd.DataFrame.from_dict(results)
table = table[['params', 'mean_test_score', 'std_test_score', 'rank_test_score']]

# %%
table
# Out:
#                                                params  ...  rank_test_score
# 0   {'criterion': 'squared_error', 'max_features':...  ...               19
# 1   {'criterion': 'squared_error', 'max_features':...  ...               19
# 2   {'criterion': 'squared_error', 'max_features':...  ...               19
# 3   {'criterion': 'squared_error', 'max_features':...  ...                5
# 4   {'criterion': 'squared_error', 'max_features':...  ...               14
# 5   {'criterion': 'squared_error', 'max_features':...  ...                9
# 6   {'criterion': 'squared_error', 'max_features':...  ...               16
# 7   {'criterion': 'squared_error', 'max_features':...  ...                7
# 8   {'criterion': 'squared_error', 'max_features':...  ...               18
# 9   {'criterion': 'absolute_error', 'max_features'...  ...               19
# 10  {'criterion': 'absolute_error', 'max_features'...  ...               19
# 11  {'criterion': 'absolute_error', 'max_features'...  ...               19
# 12  {'criterion': 'absolute_error', 'max_features'...  ...               17
# 13  {'criterion': 'absolute_error', 'max_features'...  ...               12
# 14  {'criterion': 'absolute_error', 'max_features'...  ...                2
# 15  {'criterion': 'absolute_error', 'max_features'...  ...                4
# 16  {'criterion': 'absolute_error', 'max_features'...  ...               13
# 17  {'criterion': 'absolute_error', 'max_features'...  ...               15
# 18  {'criterion': 'poisson', 'max_features': 'auto...  ...               19
# 19  {'criterion': 'poisson', 'max_features': 'auto...  ...               19
# 20  {'criterion': 'poisson', 'max_features': 'auto...  ...               19
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...  ...                8
# 22  {'criterion': 'poisson', 'max_features': 'sqrt...  ...               11
# 23  {'criterion': 'poisson', 'max_features': 'sqrt...  ...                6
# 24  {'criterion': 'poisson', 'max_features': 'log2...  ...                3
# 25  {'criterion': 'poisson', 'max_features': 'log2...  ...                1
# 26  {'criterion': 'poisson', 'max_features': 'log2...  ...               10
#
# [27 rows x 4 columns]

# %%
def get_float(prompt, default=0.0):
	val = input(prompt)
	return float(val) if val.strip() else default

def get_int(prompt, default=0):
	val = input(prompt)
	return int(val) if val.strip() else default

age_input = get_float("Age:", 30.0)
bmi_input = get_float("BMI:", 25.0)
children_input = get_float("Children:", 0.0)
sex_male_input = get_int("Sex Male 0 or 1:", 1)
smoker_yes_input = get_int("Smoker Yes 0 or 1:", 0)

# %%
# Ensure grid is defined (run cell 2 if not)
try:
	Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
	print("Future_Prediction: ", format(Future_Prediction))
except NameError:
	print("Error: 'grid' is not defined. Please run the cell where the model is trained (cell 2).")
# Out:
# Future_Prediction:  [17435.21451015]
